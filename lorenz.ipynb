# %%
# %matplotlib inline
import os
from IPython.html.widgets import interact


def plot_lorenz(smin=1, smax=40, rmin=50, rmax=110):
    # !./lorenz_sweep --sigma_min=$smin --sigma_max=$smax --sigma_steps=300 --R_min=$rmin --R_max=$rmax --R_steps=300 --kmax=16 > /dev/null
    # %run plot_kneading -f lorenz.h5 -b 5
    
interact(plot_lorenz, smin=(1, 40, 1), smax=(1, 40, 1), rmin=(50, 110, 1), rmax=(50, 110, 1));
